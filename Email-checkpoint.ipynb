# %%
from ucimlrepo import fetch_ucirepo
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix
import joblib

# %%
# Fetch dataset
spambase = fetch_ucirepo(id=94)

# Access the data as pandas DataFrames
X = spambase.data.features
y = spambase.data.targets

# Convert features and targets to DataFrames
X_df = pd.DataFrame(X, columns=spambase.variables)
y_df = pd.DataFrame(y, columns=['label'])

# Data Preprocessing
print("\nData Information:")
print(X_df.info())

print("\nFirst few rows of features:")
print(X_df.head())

print("\nFirst few rows of targets:")
print(y_df.head())

# Check for missing values
print("\nMissing values in features:")
print(X_df.isnull().sum())

print("\nMissing values in targets:")
print(y_df.isnull().sum())

# Ensure data types are correct
print("\nFeature types:\n", X_df.dtypes)
print("\nTarget types:\n", y_df.dtypes)

# Convert y_train to a 1D array
y_df = y_df.values.ravel()

# Split the dataset
X_train, X_test, y_train, y_test = train_test_split(X_df, y_df, test_size=0.2, random_state=42)

# Ensure X_train and y_train have the correct shapes
print("X_train shape:", X_train.shape)
print("y_train shape:", y_train.shape)

# Initialize and train the model
try:
    model = LogisticRegression(max_iter=1000)
    model.fit(X_train, y_train)
    print("Model trained successfully.")
except Exception as e:
    print(f"Error during model training: {e}")

# Model Evaluation
try:
    y_pred = model.predict(X_test)

    accuracy = accuracy_score(y_test, y_pred)
    precision = precision_score(y_test, y_pred)
    recall = recall_score(y_test, y_pred)
    f1 = f1_score(y_test, y_pred)
    conf_matrix = confusion_matrix(y_test, y_pred)

    print("\nModel Evaluation:")
    print(f"Accuracy: {accuracy}")
    print(f"Precision: {precision}")
    print(f"Recall: {recall}")
    print(f"F1-score: {f1}")
    print(f"Confusion Matrix:\n{conf_matrix}")
except Exception as e:
    print(f"Error during model evaluation: {e}")

# Save the model
try:
    joblib.dump(model, 'spam_classifier_model.pkl')
    print("Model saved successfully.")
except Exception as e:
    print(f"Error saving model: {e}")

# Prediction function
def predict_spam(features):
    try:
        prediction = model.predict([features])
        return "Spam" if prediction == 1 else "Ham"
    except Exception as e:
        return f"Error during prediction: {e}"

# Example usage
try:
    sample_features = X_test.iloc[0].values
    print("\nPrediction for sample features:")
    print(predict_spam(sample_features))
except Exception as e:
    print(f"Error during example prediction: {e}")
# Out:
# Data Information:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4601 entries, 0 to 4600
# Data columns (total 58 columns):
#  #   Column                                                                   Non-Null Count  Dtype
# ---  ------                                                                   --------------  -----
#  0   (word_freq_make, Feature, Continuous, None, None, None, no)              0 non-null      float64
#  1   (word_freq_address, Feature, Continuous, None, None, None, no)           0 non-null      float64
#  2   (word_freq_all, Feature, Continuous, None, None, None, no)               0 non-null      float64
#  3   (word_freq_3d, Feature, Continuous, None, None, None, no)                0 non-null      float64
#  4   (word_freq_our, Feature, Continuous, None, None, None, no)               0 non-null      float64
#  5   (word_freq_over, Feature, Continuous, None, None, None, no)              0 non-null      float64
#  6   (word_freq_remove, Feature, Continuous, None, None, None, no)            0 non-null      float64
#  7   (word_freq_internet, Feature, Continuous, None, None, None, no)          0 non-null      float64
#  8   (word_freq_order, Feature, Continuous, None, None, None, no)             0 non-null      float64
#  9   (word_freq_mail, Feature, Continuous, None, None, None, no)              0 non-null      float64
#  10  (word_freq_receive, Feature, Continuous, None, None, None, no)           0 non-null      float64
#  11  (word_freq_will, Feature, Continuous, None, None, None, no)              0 non-null      float64
#  12  (word_freq_people, Feature, Continuous, None, None, None, no)            0 non-null      float64
#  13  (word_freq_report, Feature, Continuous, None, None, None, no)            0 non-null      float64
#  14  (word_freq_addresses, Feature, Continuous, None, None, None, no)         0 non-null      float64
#  15  (word_freq_free, Feature, Continuous, None, None, None, no)              0 non-null      float64
#  16  (word_freq_business, Feature, Continuous, None, None, None, no)          0 non-null      float64
#  17  (word_freq_email, Feature, Continuous, None, None, None, no)             0 non-null      float64
#  18  (word_freq_you, Feature, Continuous, None, None, None, no)               0 non-null      float64
#  19  (word_freq_credit, Feature, Continuous, None, None, None, no)            0 non-null      float64
#  20  (word_freq_your, Feature, Continuous, None, None, None, no)              0 non-null      float64
#  21  (word_freq_font, Feature, Continuous, None, None, None, no)              0 non-null      float64
#  22  (word_freq_000, Feature, Continuous, None, None, None, no)               0 non-null      float64
#  23  (word_freq_money, Feature, Continuous, None, None, None, no)             0 non-null      float64
#  24  (word_freq_hp, Feature, Continuous, None, None, None, no)                0 non-null      float64
#  25  (word_freq_hpl, Feature, Continuous, None, None, None, no)               0 non-null      float64
#  26  (word_freq_george, Feature, Continuous, None, None, None, no)            0 non-null      float64
#  27  (word_freq_650, Feature, Continuous, None, None, None, no)               0 non-null      float64
#  28  (word_freq_lab, Feature, Continuous, None, None, None, no)               0 non-null      float64
#  29  (word_freq_labs, Feature, Continuous, None, None, None, no)              0 non-null      float64
#  30  (word_freq_telnet, Feature, Continuous, None, None, None, no)            0 non-null      float64
#  31  (word_freq_857, Feature, Continuous, None, None, None, no)               0 non-null      float64
#  32  (word_freq_data, Feature, Continuous, None, None, None, no)              0 non-null      float64
#  33  (word_freq_415, Feature, Continuous, None, None, None, no)               0 non-null      float64
#  34  (word_freq_85, Feature, Continuous, None, None, None, no)                0 non-null      float64
#  35  (word_freq_technology, Feature, Continuous, None, None, None, no)        0 non-null      float64
#  36  (word_freq_1999, Feature, Continuous, None, None, None, no)              0 non-null      float64
#  37  (word_freq_parts, Feature, Continuous, None, None, None, no)             0 non-null      float64
#  38  (word_freq_pm, Feature, Continuous, None, None, None, no)                0 non-null      float64
#  39  (word_freq_direct, Feature, Continuous, None, None, None, no)            0 non-null      float64
#  40  (word_freq_cs, Feature, Continuous, None, None, None, no)                0 non-null      float64
#  41  (word_freq_meeting, Feature, Continuous, None, None, None, no)           0 non-null      float64
#  42  (word_freq_original, Feature, Continuous, None, None, None, no)          0 non-null      float64
#  43  (word_freq_project, Feature, Continuous, None, None, None, no)           0 non-null      float64
#  44  (word_freq_re, Feature, Continuous, None, None, None, no)                0 non-null      float64
#  45  (word_freq_edu, Feature, Continuous, None, None, None, no)               0 non-null      float64
#  46  (word_freq_table, Feature, Continuous, None, None, None, no)             0 non-null      float64
#  47  (word_freq_conference, Feature, Continuous, None, None, None, no)        0 non-null      float64
#  48  (char_freq_;, Feature, Continuous, None, None, None, no)                 0 non-null      float64
#  49  (char_freq_(, Feature, Continuous, None, None, None, no)                 0 non-null      float64
#  50  (char_freq_[, Feature, Continuous, None, None, None, no)                 0 non-null      float64
#  51  (char_freq_!, Feature, Continuous, None, None, None, no)                 0 non-null      float64
#  52  (char_freq_$, Feature, Continuous, None, None, None, no)                 0 non-null      float64
#  53  (char_freq_#, Feature, Continuous, None, None, None, no)                 0 non-null      float64
#  54  (capital_run_length_average, Feature, Continuous, None, None, None, no)  0 non-null      float64
#  55  (capital_run_length_longest, Feature, Continuous, None, None, None, no)  0 non-null      float64
#  56  (capital_run_length_total, Feature, Continuous, None, None, None, no)    0 non-null      float64
#  57  (Class, Target, Binary, None, spam (1) or not spam (0), None, no)        0 non-null      float64
# dtypes: float64(58)
# memory usage: 2.0 MB
# None
#
# First few rows of features:
#    (word_freq_make, Feature, Continuous, None, None, None, no)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    (word_freq_address, Feature, Continuous, None, None, None, no)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    (word_freq_all, Feature, Continuous, None, None, None, no)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    (word_freq_3d, Feature, Continuous, None, None, None, no)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    (word_freq_our, Feature, Continuous, None, None, None, no)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    (word_freq_over, Feature, Continuous, None, None, None, no)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    (word_freq_remove, Feature, Continuous, None, None, None, no)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    (word_freq_internet, Feature, Continuous, None, None, None, no)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    (word_freq_order, Feature, Continuous, None, None, None, no)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    (word_freq_mail, Feature, Continuous, None, None, None, no)  ...  \
# 0                                                NaN            ...
# 1                                                NaN            ...
# 2                                                NaN            ...
# 3                                                NaN            ...
# 4                                                NaN            ...
#
#    (char_freq_;, Feature, Continuous, None, None, None, no)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    (char_freq_(, Feature, Continuous, None, None, None, no)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    (char_freq_[, Feature, Continuous, None, None, None, no)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    (char_freq_!, Feature, Continuous, None, None, None, no)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    (char_freq_$, Feature, Continuous, None, None, None, no)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    (char_freq_#, Feature, Continuous, None, None, None, no)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    (capital_run_length_average, Feature, Continuous, None, None, None, no)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    (capital_run_length_longest, Feature, Continuous, None, None, None, no)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    (capital_run_length_total, Feature, Continuous, None, None, None, no)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    (Class, Target, Binary, None, spam (1) or not spam (0), None, no)
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
# [5 rows x 58 columns]
#
# First few rows of targets:
#    label
# 0    NaN
# 1    NaN
# 2    NaN
# 3    NaN
# 4    NaN
#
# Missing values in features:
# (word_freq_make, Feature, Continuous, None, None, None, no)                4601
# (word_freq_address, Feature, Continuous, None, None, None, no)             4601
# (word_freq_all, Feature, Continuous, None, None, None, no)                 4601
# (word_freq_3d, Feature, Continuous, None, None, None, no)                  4601
# (word_freq_our, Feature, Continuous, None, None, None, no)                 4601
# (word_freq_over, Feature, Continuous, None, None, None, no)                4601
# (word_freq_remove, Feature, Continuous, None, None, None, no)              4601
# (word_freq_internet, Feature, Continuous, None, None, None, no)            4601
# (word_freq_order, Feature, Continuous, None, None, None, no)               4601
# (word_freq_mail, Feature, Continuous, None, None, None, no)                4601
# (word_freq_receive, Feature, Continuous, None, None, None, no)             4601
# (word_freq_will, Feature, Continuous, None, None, None, no)                4601
# (word_freq_people, Feature, Continuous, None, None, None, no)              4601
# (word_freq_report, Feature, Continuous, None, None, None, no)              4601
# (word_freq_addresses, Feature, Continuous, None, None, None, no)           4601
# (word_freq_free, Feature, Continuous, None, None, None, no)                4601
# (word_freq_business, Feature, Continuous, None, None, None, no)            4601
# (word_freq_email, Feature, Continuous, None, None, None, no)               4601
# (word_freq_you, Feature, Continuous, None, None, None, no)                 4601
# (word_freq_credit, Feature, Continuous, None, None, None, no)              4601
# (word_freq_your, Feature, Continuous, None, None, None, no)                4601
# (word_freq_font, Feature, Continuous, None, None, None, no)                4601
# (word_freq_000, Feature, Continuous, None, None, None, no)                 4601
# (word_freq_money, Feature, Continuous, None, None, None, no)               4601
# (word_freq_hp, Feature, Continuous, None, None, None, no)                  4601
# (word_freq_hpl, Feature, Continuous, None, None, None, no)                 4601
# (word_freq_george, Feature, Continuous, None, None, None, no)              4601
# (word_freq_650, Feature, Continuous, None, None, None, no)                 4601
# (word_freq_lab, Feature, Continuous, None, None, None, no)                 4601
# (word_freq_labs, Feature, Continuous, None, None, None, no)                4601
# (word_freq_telnet, Feature, Continuous, None, None, None, no)              4601
# (word_freq_857, Feature, Continuous, None, None, None, no)                 4601
# (word_freq_data, Feature, Continuous, None, None, None, no)                4601
# (word_freq_415, Feature, Continuous, None, None, None, no)                 4601
# (word_freq_85, Feature, Continuous, None, None, None, no)                  4601
# (word_freq_technology, Feature, Continuous, None, None, None, no)          4601
# (word_freq_1999, Feature, Continuous, None, None, None, no)                4601
# (word_freq_parts, Feature, Continuous, None, None, None, no)               4601
# (word_freq_pm, Feature, Continuous, None, None, None, no)                  4601
# (word_freq_direct, Feature, Continuous, None, None, None, no)              4601
# (word_freq_cs, Feature, Continuous, None, None, None, no)                  4601
# (word_freq_meeting, Feature, Continuous, None, None, None, no)             4601
# (word_freq_original, Feature, Continuous, None, None, None, no)            4601
# (word_freq_project, Feature, Continuous, None, None, None, no)             4601
# (word_freq_re, Feature, Continuous, None, None, None, no)                  4601
# (word_freq_edu, Feature, Continuous, None, None, None, no)                 4601
# (word_freq_table, Feature, Continuous, None, None, None, no)               4601
# (word_freq_conference, Feature, Continuous, None, None, None, no)          4601
# (char_freq_;, Feature, Continuous, None, None, None, no)                   4601
# (char_freq_(, Feature, Continuous, None, None, None, no)                   4601
# (char_freq_[, Feature, Continuous, None, None, None, no)                   4601
# (char_freq_!, Feature, Continuous, None, None, None, no)                   4601
# (char_freq_$, Feature, Continuous, None, None, None, no)                   4601
# (char_freq_#, Feature, Continuous, None, None, None, no)                   4601
# (capital_run_length_average, Feature, Continuous, None, None, None, no)    4601
# (capital_run_length_longest, Feature, Continuous, None, None, None, no)    4601
# (capital_run_length_total, Feature, Continuous, None, None, None, no)      4601
# (Class, Target, Binary, None, spam (1) or not spam (0), None, no)          4601
# dtype: int64
#
# Missing values in targets:
# label    4601
# dtype: int64
#
# Feature types:
#  (word_freq_make, Feature, Continuous, None, None, None, no)                float64
# (word_freq_address, Feature, Continuous, None, None, None, no)             float64
# (word_freq_all, Feature, Continuous, None, None, None, no)                 float64
# (word_freq_3d, Feature, Continuous, None, None, None, no)                  float64
# (word_freq_our, Feature, Continuous, None, None, None, no)                 float64
# (word_freq_over, Feature, Continuous, None, None, None, no)                float64
# (word_freq_remove, Feature, Continuous, None, None, None, no)              float64
# (word_freq_internet, Feature, Continuous, None, None, None, no)            float64
# (word_freq_order, Feature, Continuous, None, None, None, no)               float64
# (word_freq_mail, Feature, Continuous, None, None, None, no)                float64
# (word_freq_receive, Feature, Continuous, None, None, None, no)             float64
# (word_freq_will, Feature, Continuous, None, None, None, no)                float64
# (word_freq_people, Feature, Continuous, None, None, None, no)              float64
# (word_freq_report, Feature, Continuous, None, None, None, no)              float64
# (word_freq_addresses, Feature, Continuous, None, None, None, no)           float64
# (word_freq_free, Feature, Continuous, None, None, None, no)                float64
# (word_freq_business, Feature, Continuous, None, None, None, no)            float64
# (word_freq_email, Feature, Continuous, None, None, None, no)               float64
# (word_freq_you, Feature, Continuous, None, None, None, no)                 float64
# (word_freq_credit, Feature, Continuous, None, None, None, no)              float64
# (word_freq_your, Feature, Continuous, None, None, None, no)                float64
# (word_freq_font, Feature, Continuous, None, None, None, no)                float64
# (word_freq_000, Feature, Continuous, None, None, None, no)                 float64
# (word_freq_money, Feature, Continuous, None, None, None, no)               float64
# (word_freq_hp, Feature, Continuous, None, None, None, no)                  float64
# (word_freq_hpl, Feature, Continuous, None, None, None, no)                 float64
# (word_freq_george, Feature, Continuous, None, None, None, no)              float64
# (word_freq_650, Feature, Continuous, None, None, None, no)                 float64
# (word_freq_lab, Feature, Continuous, None, None, None, no)                 float64
# (word_freq_labs, Feature, Continuous, None, None, None, no)                float64
# (word_freq_telnet, Feature, Continuous, None, None, None, no)              float64
# (word_freq_857, Feature, Continuous, None, None, None, no)                 float64
# (word_freq_data, Feature, Continuous, None, None, None, no)                float64
# (word_freq_415, Feature, Continuous, None, None, None, no)                 float64
# (word_freq_85, Feature, Continuous, None, None, None, no)                  float64
# (word_freq_technology, Feature, Continuous, None, None, None, no)          float64
# (word_freq_1999, Feature, Continuous, None, None, None, no)                float64
# (word_freq_parts, Feature, Continuous, None, None, None, no)               float64
# (word_freq_pm, Feature, Continuous, None, None, None, no)                  float64
# (word_freq_direct, Feature, Continuous, None, None, None, no)              float64
# (word_freq_cs, Feature, Continuous, None, None, None, no)                  float64
# (word_freq_meeting, Feature, Continuous, None, None, None, no)             float64
# (word_freq_original, Feature, Continuous, None, None, None, no)            float64
# (word_freq_project, Feature, Continuous, None, None, None, no)             float64
# (word_freq_re, Feature, Continuous, None, None, None, no)                  float64
# (word_freq_edu, Feature, Continuous, None, None, None, no)                 float64
# (word_freq_table, Feature, Continuous, None, None, None, no)               float64
# (word_freq_conference, Feature, Continuous, None, None, None, no)          float64
# (char_freq_;, Feature, Continuous, None, None, None, no)                   float64
# (char_freq_(, Feature, Continuous, None, None, None, no)                   float64
# (char_freq_[, Feature, Continuous, None, None, None, no)                   float64
# (char_freq_!, Feature, Continuous, None, None, None, no)                   float64
# (char_freq_$, Feature, Continuous, None, None, None, no)                   float64
# (char_freq_#, Feature, Continuous, None, None, None, no)                   float64
# (capital_run_length_average, Feature, Continuous, None, None, None, no)    float64
# (capital_run_length_longest, Feature, Continuous, None, None, None, no)    float64
# (capital_run_length_total, Feature, Continuous, None, None, None, no)      float64
# (Class, Target, Binary, None, spam (1) or not spam (0), None, no)          float64
# dtype: object
#
# Target types:
#  label    float64
# dtype: object
# X_train shape: (3680, 58)
# y_train shape: (3680,)
# Error during model training: Input X contains NaN.
# LogisticRegression does not accept missing values encoded as NaN natively. For supervised learning, you might want to consider sklearn.ensemble.HistGradientBoostingClassifier and Regressor which accept missing values encoded as NaNs natively. Alternatively, it is possible to preprocess the data, for instance by using an imputer transformer in a pipeline or drop samples with missing values. See https://scikit-learn.org/stable/modules/impute.html You can find a list of all estimators that handle NaN values at the following page: https://scikit-learn.org/stable/modules/impute.html#estimators-that-handle-nan-values
# Error during model evaluation: This LogisticRegression instance is not fitted yet. Call 'fit' with appropriate arguments before using this estimator.
# Model saved successfully.
#
# Prediction for sample features:
# Error during prediction: This LogisticRegression instance is not fitted yet. Call 'fit' with appropriate arguments before using this estimator.
